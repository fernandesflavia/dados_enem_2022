# %% [markdown]
# #**PROJETO ANÁLISE ESTATÍSTICA DO ENEM 2019**

# %%
import numpy as np
import pandas as pd

# %%
#montar o drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv('/content/drive/MyDrive/Microdados-enem2022/MICRODADOS_ENEM_2022.csv',
                    sep=';',encoding='iso-8859-1')
# encoding: codificação de caracteres, normalmente utiliza-se o iso-8859-1, utf-8, latin-1)

# %% [markdown]
# #Extração e Limpeza dos dados

# %%
pd.options.display.max_columns = 44

# %%
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %%
dados.shape
# Out:
# (3476105, 76)

# %%
# Análise dos tipos de atributos.
# object: strings
# int64: inteiros
# float64: reais
# complex: complexos
dados.dtypes
# Out:
# NU_INSCRICAO        int64
# NU_ANO              int64
# TP_FAIXA_ETARIA     int64
# TP_SEXO            object
# TP_ESTADO_CIVIL     int64
#                     ...
# Q021               object
# Q022               object
# Q023               object
# Q024               object
# Q025               object
# Length: 76, dtype: object

# %%
dados1 = dados.drop(columns=['CO_MUNICIPIO_PROVA'])

# %%
dados1.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %%
dados1 = dados1.drop(columns=['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC','SG_UF_ESC','TP_DEPENDENCIA_ADM_ESC','TP_SIT_FUNC_ESC','Q004',
                              'Q005','Q006','Q007','Q008','Q009','Q010','Q011','Q012','Q013','Q014','Q015','Q016','Q017','Q018','Q019','Q020'],)

# %%
dados1.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  TP_LOCALIZACAO_ESC         NO_MUNICIPIO_PROVA  \
# ...

# %%
dados1 = dados1.drop(columns=['NU_NOTA_COMP1','NU_NOTA_COMP2','NU_NOTA_COMP3','NU_NOTA_COMP4','NU_NOTA_COMP5','Q001','Q002','Q003','Q021','Q022','Q023','Q024','Q025'],)

# %%
dados1.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  TP_LOCALIZACAO_ESC         NO_MUNICIPIO_PROVA  \
# ...

# %%
dados1 = dados1.drop(columns=['TX_GABARITO_CN','TX_GABARITO_CH','TX_GABARITO_LC','TX_GABARITO_MT',],)

# %%
dados1.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  TP_LOCALIZACAO_ESC         NO_MUNICIPIO_PROVA  \
# ...

# %%
dados1 = dados1.drop(columns=['TX_RESPOSTAS_CN','TX_RESPOSTAS_CH','TX_RESPOSTAS_LC','TX_RESPOSTAS_MT'],)

# %%
dados1.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210057943671    2022               14       M                2
# 1  210057516120    2022               14       M                2
# 2  210057280536    2022                5       F                1
# 3  210055724397    2022                6       M                1
# 4  210055097896    2022                4       M                0
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1                2          1
# 1            1                 1                1               16          1
# 2            2                 1                1                2          1
# 3            3                 1                1                2          1
# 4            3                 1                1                1          1
#
#    TP_ENSINO  IN_TREINEIRO  TP_LOCALIZACAO_ESC         NO_MUNICIPIO_PROVA  \
# ...

# %%
dados1.shape
# Out:
# (3476105, 31)

# %%
dados1.to_csv('enem_2022_tratado.csv', encoding = 'iso-8859-1', index = False)
